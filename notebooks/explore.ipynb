# %%
import os
import sys

# Import Code modules
module_path = os.path.abspath(os.path.join('../code'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Con'd import
from data_fetcher import DataFetcher
from endpoint_type import EndpointType
from db_connector import DBConnector
from flusurv_params import *
from fluview_params import *
from gft_params import *

db_connector = DBConnector()

# %%
flusurv_param = FluSurvParams(
    epiweeks = ["202003", "202004"], 
    regions = [FluSurvRegion.CA]
)

DataFetcher.fetch(EndpointType.FLUSURV, param=flusurv_param)
# Out:
#   release_date location   issue  epiweek  lag  rate_age_0  rate_age_1  \
# 0   2020-11-06       CA  202044   202003   41         3.5         1.5
# 1   2020-11-06       CA  202044   202004   40         1.5         2.1
#
#    rate_age_2  rate_age_3  rate_age_4  rate_overall
# 0         2.6         5.2        12.0           4.4
# 1         1.7         5.5        17.6           4.9

# %%
fluview_param = FluViewParams(
    epiweeks = ["202001", "202002", "202008-202010"],
    regions = [FluViewRegion.CEN2, FluViewRegion.HHS1]
)

DataFetcher.fetch(
    endpoint = EndpointType.FLUVIEW, 
    param = fluview_param
)
# Out:
#   release_date region   issue  epiweek  lag  num_ili  num_patients  \
# 0   2021-10-08   cen2  202139   202001   91    15159        245889
# 1   2021-10-08   hhs1  202139   202001   91     5394        126801
# 2   2021-10-08   cen2  202139   202002   90    13030        243510
# 3   2021-10-08   hhs1  202139   202002   90     5310        136068
# 4   2021-10-08   cen2  202139   202008   84    11450        234069
# 5   2021-10-08   hhs1  202139   202008   84     7692        130014
# 6   2021-10-08   cen2  202139   202009   83     9908        236494
# 7   2021-10-08   hhs1  202139   202009   83     6319        133257
# 8   2021-10-08   cen2  202139   202010   82    11653        248556
# 9   2021-10-08   hhs1  202139   202010   82     5944        129920
#
#    num_providers  num_age_0  num_age_1 num_age_2  num_age_3  num_age_4  \
# 0            383       4069       3952      None       4347       1547
# 1            264        980       1379      None       1834        676
# ...

# %%
DBConnector.resolveTableName(EndpointType.FLUSURV)
# Out:
# 'flusurv'

# %%
query = f"""
select * from {DBConnector.resolveTableName(EndpointType.FLUVIEW)}
group by region
"""

db_connector.read(query)
# Out:
#   release_date region   issue  epiweek  lag  num_ili  num_patients  \
# 0   2021-10-08   cen2  202139   202001   91    15159        245889
# 1   2021-10-08   hhs1  202139   202001   91     5394        126801
#
#    num_providers  num_age_0  num_age_1 num_age_2  num_age_3  num_age_4  \
# 0            383       4069       3952      None       4347       1547
# 1            264        980       1379      None       1834        676
#
#    num_age_5     wili      ili
# 0       1244  6.11285  6.16498
# 1        525  3.92170  4.25391

# %%
gft_param = GTFParams(
    epiweeks = "202001",
    regions = [GFTRegion.CEN1, GFTRegion.HHS1]
)

DataFetcher.fetch(
    endpoint = EndpointType.GFT, 
    param = gft_param
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/native_env/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1275                 if not evt_handled:
# -> 1276                     self.dialect.do_execute(
#    1277                         cursor, statement, parameters, context
#
# ~/opt/anaconda3/envs/native_env/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     592     def do_execute(self, cursor, statement, parameters, context=None):
# --> 593         cursor.execute(statement, parameters)
#     594
#
# OperationalError: near ")": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ...
